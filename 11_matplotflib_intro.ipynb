# %% [markdown]
# <a href="https://colab.research.google.com/github/sebakrys/data-science-bootcamp-A-Z/blob/main/11_matplotflib_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install matplotlib

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.8.0'

# %%
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns
sns.set()

# %%
fig = plt.figure()
fig.show()

# %% [markdown]
# # Wykres Liniowy

# %%
plt.plot([0, 1], [0, 3])

# %%
plt.plot([0, 1], [0, 3], label='line', color='green')
plt.xlabel("axis X")
plt.ylabel("axis Y")
plt.title("Tytuł wykresu")
_ = plt.legend()

# %%
plt.plot([0, 1, 2], [0, 3, 2], label='line', color='green')
plt.xlabel("axis X")
plt.ylabel("axis Y")
plt.title("Tytuł wykresu")
_ = plt.legend()

# %%
x = np.arange(-3.2, 3.2, 0.1)
x_sin = np.sin(x)
x_cos = np.cos(x)
plt.plot(x, x_sin)
plt.plot(x, x_cos)

# %% [markdown]
# # Twoerzenie wielu wykresów

# %%
plt.subplot(121)#1 - liczba wielrszy wykresów, 2 - liczba kolumn wykresów, 1 - nr wykresu
plt.plot([1, 2, 3], [3, 2, 5])

plt.subplot(122)#1 - liczba wielrszy wykresów, 2 - liczba kolumn wykresów, 2 - nr wykresu
plt.plot([1, 2, 3], [2, 4, 3], 'r--')

# %%
fig = plt.figure(figsize=(12, 8))

plt.subplot(131)#1 - liczba wielrszy wykresów, 3 - liczba kolumn wykresów, 1 - nr wykresu
plt.plot([1, 2, 3], [3, 2, 5])

plt.subplot(132)#1 - liczba wielrszy wykresów, 3 - liczba kolumn wykresów, 2 - nr wykresu
plt.plot([1, 2, 3], [2, 4, 3], 'r--')

plt.subplot(133)#1 - liczba wielrszy wykresów, 3 - liczba kolumn wykresów, 3 - nr wykresu
plt.plot([1, 2, 3], [2, 4, 3], 'bo-')

# %% [markdown]
# # Wykresy Słupkowe

# %%
plt.bar(x=[0, 1, 2, 3], height=[1.2, 3.2, 1.2, 5.2])
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(x=['a', 'b', 'c', 'd'], height=[1.2, 3.2, 1.2, 5.2])
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(y=['a', 'b', 'c', 'd'], width=[1.2, 3.2, 1.2, 5.2])
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# # Wykresy punktowe

# %%
x1 = np.random.randn(400)
x2 = np.random.randn(400)
plt.scatter(x=x1, y=x2)

# %%
x3 = np.random.randn(400) * 50
plt.scatter(x=x1, y=x2, s = x3)
# Out:
# /usr/local/lib/python3.10/dist-packages/matplotlib/collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
plt.scatter(x=x1, y=x2, s = x3, alpha=0.5)
# Out:
# /usr/local/lib/python3.10/dist-packages/matplotlib/collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
