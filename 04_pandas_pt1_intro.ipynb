# %% [markdown]
# <a href="https://colab.research.google.com/github/sebakrys/data-science-bootcamp-A-Z/blob/main/04_pandas_pt1_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas

# %%
import pandas as pd
pd.__version__
# Out:
# '2.1.4'

# %% [markdown]
# ## Series

# %%
s = pd.Series(data=[3, 2, 4, 6])
s
# Out:
# 0    3
# 1    2
# 2    4
# 3    6
# dtype: int64

# %%
s = pd.Series(data=[3, 2, 4, 6], index=["a", "b", "c", "d"], name="Sample")
s
# Out:
# a    3
# b    2
# c    4
# d    6
# Name: Sample, dtype: int64

# %%
s = pd.Series(data=[3., 2, 4, 6], index=["a", "b", "c", "d"], name="sample")
s
# Out:
# a    3.0
# b    2.0
# c    4.0
# d    6.0
# Name: sample, dtype: float64

# %%
import numpy as np

s = pd.Series(data=[3., np.nan, 4, 6], index=["a", "b", "c", "d"], name="sample")
s
# Out:
# a    3.0
# b    NaN
# c    4.0
# d    6.0
# Name: sample, dtype: float64

# %%
s = pd.Series(data=[True, False, True])
s
# Out:
# 0     True
# 1    False
# 2     True
# dtype: bool

# %%
s = pd.Series(data=np.arange(10, 20), index=pd.date_range(start='20200101', periods=10))
s
# Out:
# 2020-01-01    10
# 2020-01-02    11
# 2020-01-03    12
# 2020-01-04    13
# 2020-01-05    14
# 2020-01-06    15
# 2020-01-07    16
# 2020-01-08    17
# 2020-01-09    18
# 2020-01-10    19
# Freq: D, dtype: int64

# %%
list(s.index)
# Out:
# [Timestamp('2020-01-01 00:00:00'),
#  Timestamp('2020-01-02 00:00:00'),
#  Timestamp('2020-01-03 00:00:00'),
#  Timestamp('2020-01-04 00:00:00'),
#  Timestamp('2020-01-05 00:00:00'),
#  Timestamp('2020-01-06 00:00:00'),
#  Timestamp('2020-01-07 00:00:00'),
#  Timestamp('2020-01-08 00:00:00'),
#  Timestamp('2020-01-09 00:00:00'),
#  Timestamp('2020-01-10 00:00:00')]

# %%
s = pd.Series(data=['python', 'java', 'c++', 'sql'], name='languages')
s
# Out:
# 0    python
# 1      java
# 2       c++
# 3       sql
# Name: languages, dtype: object

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
s.values
# Out:
# array(['python', 'java', 'c++', 'sql'], dtype=object)

# %%
s.dtypes
# Out:
# dtype('O')

# %%
s.shape
# Out:
# (4,)

# %%
price = pd.Series(data={'Apple':200, 'CD Projekt':60, 'Amazon':1900, 'KGHM':np.nan})
price
# Out:
# Apple          200.0
# CD Projekt      60.0
# Amazon        1900.0
# KGHM             NaN
# dtype: float64

# %%
price['CD Projekt']
# Out:
# 60.0

# %%
print(price[1])
# Out:
# 60.0
# <ipython-input-18-c91d6da71123>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(price[1])

# %%
print(price.iloc[1])
# Out:
# 60.0

# %%
price.count()
# Out:
# 3

# %%
price.value_counts(dropna=False)
# Out:
# 200.0     1
# 60.0      1
# 1900.0    1
# NaN       1
# Name: count, dtype: int64

# %%
price.sum()
# Out:
# 2160.0

# %%
price.min()
# Out:
# 60.0

# %%
price.std()
# Out:
# 1024.3046421841502

# %%
price.describe()
# Out:
# count       3.000000
# mean      720.000000
# std      1024.304642
# min        60.000000
# 25%       130.000000
# 50%       200.000000
# 75%      1050.000000
# max      1900.000000
# dtype: float64

# %%
price.nlargest(2)
# Out:
# Amazon    1900.0
# Apple      200.0
# dtype: float64

# %%
price.nsmallest(1)
# Out:
# CD Projekt    60.0
# dtype: float64

# %%
price.rank()
# Out:
# Apple         2.0
# CD Projekt    1.0
# Amazon        3.0
# KGHM          NaN
# dtype: float64

# %%
price.sort_values()
# Out:
# CD Projekt      60.0
# Apple          200.0
# Amazon        1900.0
# KGHM             NaN
# dtype: float64

# %%
price.sort_values(ascending=False)
# Out:
# Amazon        1900.0
# Apple          200.0
# CD Projekt      60.0
# KGHM             NaN
# dtype: float64

# %%
price.apply(lambda x: x * 3.8)
# Out:
# Apple          760.0
# CD Projekt     228.0
# Amazon        7220.0
# KGHM             NaN
# dtype: float64

# %%
price_pln = price.apply(lambda x: x * 3.8)
price_pln
# Out:
# Apple          760.0
# CD Projekt     228.0
# Amazon        7220.0
# KGHM             NaN
# dtype: float64

# %% [markdown]
# ## DataFrame

# %%
df = pd.DataFrame(data=[12, 12, 32])
df
# Out:
#     0
# 0  12
# 1  12
# 2  32

# %%
df = pd.DataFrame(data=[12, 12, 32], index=['first', 'second', 'third'], columns=['col_1'])
df
# Out:
#         col_1
# first      12
# second     12
# third      32

# %%
df = pd.DataFrame(data={'WIG20':['PKN ORLEN', 'PKO BP'],
                        'mWIG20':['Amica', 'Playway']})
df
# Out:
#        WIG20   mWIG20
# 0  PKN ORLEN    Amica
# 1     PKO BP  Playway

# %%
df = pd.DataFrame(data=[[12, 12, 32], [23, 12, 10]], index=['first', 'second'], columns=['col_1', 'col_2', 'col_3'])
df
# Out:
#         col_1  col_2  col_3
# first      12     12     32
# second     23     12     10

# %%
df.columns
# Out:
# Index(['col_1', 'col_2', 'col_3'], dtype='object')

# %%
df.index
# Out:
# Index(['first', 'second'], dtype='object')

# %%
df.values
# Out:
# array([[12, 12, 32],
#        [23, 12, 10]])

# %%
df.info
# Out:
# <bound method DataFrame.info of         col_1  col_2  col_3
# first      12     12     32
# second     23     12     10>

# %%
df.describe()
# Out:
#            col_1  col_2      col_3
# count   2.000000    2.0   2.000000
# mean   17.500000   12.0  21.000000
# std     7.778175    0.0  15.556349
# min    12.000000   12.0  10.000000
# 25%    14.750000   12.0  15.500000
# 50%    17.500000   12.0  21.000000
# 75%    20.250000   12.0  26.500000
# max    23.000000   12.0  32.000000

# %%
df.describe().T
# Out:
#        count  mean        std   min    25%   50%    75%   max
# col_1    2.0  17.5   7.778175  12.0  14.75  17.5  20.25  23.0
# col_2    2.0  12.0   0.000000  12.0  12.00  12.0  12.00  12.0
# col_3    2.0  21.0  15.556349  10.0  15.50  21.0  26.50  32.0
