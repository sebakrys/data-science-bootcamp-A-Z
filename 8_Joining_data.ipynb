# %% [markdown]
# <a href="https://colab.research.google.com/github/sebakrys/data-science-bootcamp-A-Z/blob/main/8_Joining_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Joining Data

# %%
import pandas as pd
import numpy as np

print('Numpy:', np.__version__)
print('Pandas:', pd.__version__)
# Out:
# Numpy: 1.26.4
# Pandas: 2.1.4

# %%
from os import name
def fetch_financial_data(company="AMZN"):
  """Fetch stock data from stooq.pl service"""
  import pandas_datareader.data as web
  return web.DataReader(name=company, data_source='stooq')

apple = fetch_financial_data('AAPL')
amazon = fetch_financial_data('AMZN')
google = fetch_financial_data('GOOGL')
uber = fetch_financial_data('UBER')

# %%
google.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1256 entries, 2024-09-27 to 2019-10-02
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   google_open    1256 non-null   float64
#  1   google_high    1256 non-null   float64
#  2   google_low     1256 non-null   float64
#  3   google_close   1256 non-null   float64
#  4   google_volume  1256 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 58.9 KB

# %%
apple.head()
# Out:
#                Open    High     Low   Close      Volume
# Date
# 2024-09-27  228.460  229.52  227.30  227.79  34025967.0
# 2024-09-26  227.300  228.50  225.41  227.52  36636707.0
# 2024-09-25  224.930  227.29  224.02  226.37  42308715.0
# 2024-09-24  228.645  229.35  225.73  227.37  43556068.0
# 2024-09-23  227.340  229.45  225.81  226.47  54146023.0

# %%
apple.columns = ['apple_'+col.lower() for col in apple.columns]
amazon.columns = ['amazon_'+col.lower() for col in amazon.columns]
google.columns = ['google_'+col.lower() for col in google.columns]
uber.columns = ['uber_'+col.lower() for col in uber.columns]

# %%
apple.head()
# Out:
#             apple_open  apple_high  apple_low  apple_close  apple_volume
# Date
# 2024-09-27     228.460      229.52     227.30       227.79    34025967.0
# 2024-09-26     227.300      228.50     225.41       227.52    36636707.0
# 2024-09-25     224.930      227.29     224.02       226.37    42308715.0
# 2024-09-24     228.645      229.35     225.73       227.37    43556068.0
# 2024-09-23     227.340      229.45     225.81       226.47    54146023.0

# %% [markdown]
# ## Data concatenation

# %%
df = pd.concat(objs=[apple, amazon, google, uber])

# %%
pd.set_option('display.float_format', lambda x: f'{x:.2f}')
df.describe()
# Out:
#        apple_open  apple_high  apple_low  apple_close  apple_volume  \
# count     1256.00     1256.00    1256.00      1256.00       1256.00
# mean       144.57      146.19     143.07       144.71   94507368.52
# std         41.78       42.04      41.49        41.77   53678448.03
# min         53.34       53.96      52.20        53.46   24048344.00
# 25%        122.41      123.55     120.71       122.24   59186518.89
# 50%        147.99      149.82     146.76       148.26   80055332.34
# 75%        173.46      175.21     171.99       173.83  112468935.49
# max        236.48      237.23     233.09       234.82  434708544.96
#
#        amazon_open  amazon_high  amazon_low  amazon_close  amazon_volume  \
# count      1256.00      1256.00     1256.00       1256.00        1256.00
# mean        140.85       142.57      139.01        140.82    69688410.02
# std          31.34        31.46       31.08         31.24    33616242.21
# min          82.08        83.48       81.30         81.82    17626740.00
# 25%         113.77       116.06      112.39        114.27    48013773.00
# 50%         148.53       151.12      146.06        148.38    61119081.50
# 75%         166.56       168.16      164.55        166.30    82293532.25
# max         200.09       201.20      199.04        200.00   311345660.00
#
#        google_open  google_high  google_low  google_close  google_volume  \
# count      1256.00      1256.00     1256.00       1256.00        1256.00
# mean        113.39       114.68      112.18        113.46    33084310.64
# std          31.75        31.96       31.49         31.71    14477502.44
# min          52.82        53.35       50.44         52.71     9312760.00
# 25%          88.07        88.85       86.92         88.01    23655290.00
# 50%         115.10       116.63      113.65        114.77    29388713.50
# 75%         137.43       138.53      136.06        137.48    37543859.50
# max         190.31       191.75      189.03        191.18   123199220.00
#
#        uber_open  uber_high  uber_low  uber_close  uber_volume
# count    1256.00    1256.00   1256.00     1256.00      1256.00
# mean       43.08      43.88     42.25       43.08  25145313.88
# std        15.02      15.12     14.86       14.97  17491049.99
# min        15.96      17.80     13.71       14.82   5200356.00
# 25%        31.20      31.82     30.50       31.19  16064436.50
# 50%        39.33      40.22     38.66       39.56  21062626.50
# 75%        52.08      52.92     50.65       51.73  29055314.75
# max        81.94      82.14     80.79       81.39 364261230.00

# %%
df.corr()
# Out:
#                apple_open  apple_high  apple_low  apple_close  apple_volume  \
# apple_open           1.00        1.00       1.00         1.00         -0.58
# apple_high           1.00        1.00       1.00         1.00         -0.57
# apple_low            1.00        1.00       1.00         1.00         -0.59
# apple_close          1.00        1.00       1.00         1.00         -0.58
# apple_volume        -0.58       -0.57      -0.59        -0.58          1.00
# amazon_open           NaN         NaN        NaN          NaN           NaN
# amazon_high           NaN         NaN        NaN          NaN           NaN
# amazon_low            NaN         NaN        NaN          NaN           NaN
# amazon_close          NaN         NaN        NaN          NaN           NaN
# amazon_volume         NaN         NaN        NaN          NaN           NaN
# google_open           NaN         NaN        NaN          NaN           NaN
# google_high           NaN         NaN        NaN          NaN           NaN
# google_low            NaN         NaN        NaN          NaN           NaN
# google_close          NaN         NaN        NaN          NaN           NaN
# google_volume         NaN         NaN        NaN          NaN           NaN
# uber_open             NaN         NaN        NaN          NaN           NaN
# uber_high             NaN         NaN        NaN          NaN           NaN
# uber_low              NaN         NaN        NaN          NaN           NaN
# uber_close            NaN         NaN        NaN          NaN           NaN
# uber_volume           NaN         NaN        NaN          NaN           NaN
#
#                amazon_open  amazon_high  amazon_low  amazon_close  \
# apple_open             NaN          NaN         NaN           NaN
# apple_high             NaN          NaN         NaN           NaN
# apple_low              NaN          NaN         NaN           NaN
# apple_close            NaN          NaN         NaN           NaN
# apple_volume           NaN          NaN         NaN           NaN
# amazon_open           1.00         1.00        1.00          1.00
# amazon_high           1.00         1.00        1.00          1.00
# amazon_low            1.00         1.00        1.00          1.00
# amazon_close          1.00         1.00        1.00          1.00
# amazon_volume        -0.23        -0.22       -0.25         -0.23
# google_open            NaN          NaN         NaN           NaN
# google_high            NaN          NaN         NaN           NaN
# google_low             NaN          NaN         NaN           NaN
# google_close           NaN          NaN         NaN           NaN
# google_volume          NaN          NaN         NaN           NaN
# uber_open              NaN          NaN         NaN           NaN
# uber_high              NaN          NaN         NaN           NaN
# uber_low               NaN          NaN         NaN           NaN
# uber_close             NaN          NaN         NaN           NaN
# uber_volume            NaN          NaN         NaN           NaN
#
#                amazon_volume  google_open  google_high  google_low  \
# apple_open               NaN          NaN          NaN         NaN
# apple_high               NaN          NaN          NaN         NaN
# apple_low                NaN          NaN          NaN         NaN
# apple_close              NaN          NaN          NaN         NaN
# apple_volume             NaN          NaN          NaN         NaN
# amazon_open            -0.23          NaN          NaN         NaN
# amazon_high            -0.22          NaN          NaN         NaN
# amazon_low             -0.25          NaN          NaN         NaN
# amazon_close           -0.23          NaN          NaN         NaN
# amazon_volume           1.00          NaN          NaN         NaN
# google_open              NaN         1.00         1.00        1.00
# google_high              NaN         1.00         1.00        1.00
# google_low               NaN         1.00         1.00        1.00
# google_close             NaN         1.00         1.00        1.00
# google_volume            NaN        -0.28        -0.27       -0.29
# uber_open                NaN          NaN          NaN         NaN
# uber_high                NaN          NaN          NaN         NaN
# uber_low                 NaN          NaN          NaN         NaN
# uber_close               NaN          NaN          NaN         NaN
# uber_volume              NaN          NaN          NaN         NaN
#
#                google_close  google_volume  uber_open  uber_high  uber_low  \
# apple_open              NaN            NaN        NaN        NaN       NaN
# apple_high              NaN            NaN        NaN        NaN       NaN
# apple_low               NaN            NaN        NaN        NaN       NaN
# apple_close             NaN            NaN        NaN        NaN       NaN
# apple_volume            NaN            NaN        NaN        NaN       NaN
# amazon_open             NaN            NaN        NaN        NaN       NaN
# amazon_high             NaN            NaN        NaN        NaN       NaN
# amazon_low              NaN            NaN        NaN        NaN       NaN
# amazon_close            NaN            NaN        NaN        NaN       NaN
# amazon_volume           NaN            NaN        NaN        NaN       NaN
# google_open            1.00          -0.28        NaN        NaN       NaN
# google_high            1.00          -0.27        NaN        NaN       NaN
# google_low             1.00          -0.29        NaN        NaN       NaN
# google_close           1.00          -0.28        NaN        NaN       NaN
# google_volume         -0.28           1.00        NaN        NaN       NaN
# uber_open               NaN            NaN       1.00       1.00      1.00
# uber_high               NaN            NaN       1.00       1.00      1.00
# uber_low                NaN            NaN       1.00       1.00      1.00
# uber_close              NaN            NaN       1.00       1.00      1.00
# uber_volume             NaN            NaN      -0.21      -0.20     -0.22
#
#                uber_close  uber_volume
# apple_open            NaN          NaN
# apple_high            NaN          NaN
# apple_low             NaN          NaN
# apple_close           NaN          NaN
# apple_volume          NaN          NaN
# amazon_open           NaN          NaN
# amazon_high           NaN          NaN
# amazon_low            NaN          NaN
# amazon_close          NaN          NaN
# amazon_volume         NaN          NaN
# google_open           NaN          NaN
# google_high           NaN          NaN
# google_low            NaN          NaN
# google_close          NaN          NaN
# google_volume         NaN          NaN
# uber_open            1.00        -0.21
# uber_high            1.00        -0.20
# uber_low             1.00        -0.22
# uber_close           1.00        -0.21
# uber_volume         -0.21         1.00

# %%
df.columns
# Out:
# Index(['apple_open', 'apple_high', 'apple_low', 'apple_close', 'apple_volume',
#        'amazon_open', 'amazon_high', 'amazon_low', 'amazon_close',
#        'amazon_volume', 'google_open', 'google_high', 'google_low',
#        'google_close', 'google_volume', 'uber_open', 'uber_high', 'uber_low',
#        'uber_close', 'uber_volume'],
#       dtype='object')

# %%
closes = [col for col in df.columns if col.endswith('close')]
closes
# Out:
# ['apple_close', 'amazon_close', 'google_close', 'uber_close']

# %%
df[closes].corr()
# Out:
#               apple_close  amazon_close  google_close  uber_close
# apple_close          1.00           NaN           NaN         NaN
# amazon_close          NaN          1.00           NaN         NaN
# google_close          NaN           NaN          1.00         NaN
# uber_close            NaN           NaN           NaN        1.00

# %%
closes_volume = [col for col in df.columns if col.endswith('close') or col.endswith('volume')]
closes_volume
# Out:
# ['apple_close',
#  'apple_volume',
#  'amazon_close',
#  'amazon_volume',
#  'google_close',
#  'google_volume',
#  'uber_close',
#  'uber_volume']

# %%
df[closes_volume].corr()
# Out:
#                apple_close  apple_volume  amazon_close  amazon_volume  \
# apple_close           1.00         -0.58           NaN            NaN
# apple_volume         -0.58          1.00           NaN            NaN
# amazon_close           NaN           NaN          1.00          -0.23
# amazon_volume          NaN           NaN         -0.23           1.00
# google_close           NaN           NaN           NaN            NaN
# google_volume          NaN           NaN           NaN            NaN
# uber_close             NaN           NaN           NaN            NaN
# uber_volume            NaN           NaN           NaN            NaN
#
#                google_close  google_volume  uber_close  uber_volume
# apple_close             NaN            NaN         NaN          NaN
# apple_volume            NaN            NaN         NaN          NaN
# amazon_close            NaN            NaN         NaN          NaN
# amazon_volume           NaN            NaN         NaN          NaN
# google_close           1.00          -0.28         NaN          NaN
# google_volume         -0.28           1.00         NaN          NaN
# uber_close              NaN            NaN        1.00        -0.21
# uber_volume             NaN            NaN       -0.21         1.00

# %% [markdown]
# ## Append

# %%
uber.head()
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2024-09-27      77.03      77.08     75.70       75.75      7580133
# 2024-09-26      78.36      78.45     75.13       76.69     14788553
# 2024-09-25      77.51      78.28     77.08       77.14     12552602
# 2024-09-24      76.00      77.51     75.97       77.44     16099212
# 2024-09-23      75.11      75.27     73.78       74.71      8285323

# %%
uber_6 = uber[uber.index.month == 6]
uber_6
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2024-06-28      70.81      73.26     70.77       72.68     21375880
# 2024-06-27      70.98      71.32     70.07       70.34      9650481
# 2024-06-26      70.94      71.60     70.55       70.85     10232568
# 2024-06-25      71.86      72.94     70.22       71.38     18911562
# 2024-06-24      69.83      71.23     69.75       70.54     12479277
# ...               ...        ...       ...         ...          ...
# 2020-06-05      37.53      38.78     36.92       37.21     30393429
# 2020-06-04      36.42      37.30     36.28       36.43     17423577
# 2020-06-03      36.20      37.37     36.14       36.75     23051776
# 2020-06-02      36.16      36.42     35.26       35.81     19328415
# 2020-06-01      35.64      36.39     35.16       35.82     21893806
#
# [105 rows x 5 columns]

# %%
uber_7 = uber[uber.index.month == 7]
uber_7
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2024-07-31      63.88      65.18     63.66       64.47     18209679
# 2024-07-30      64.15      64.77     62.61       63.09     16506187
# 2024-07-29      64.83      65.26     63.72       63.76     16906996
# 2024-07-26      66.10      66.26     64.18       64.40     17379446
# 2024-07-25      66.00      69.37     64.40       65.74     22596919
# ...               ...        ...       ...         ...          ...
# 2020-07-08      33.21      33.97     32.68       33.93     24602369
# 2020-07-07      32.46      33.56     32.39       32.82     34874658
# 2020-07-06      33.10      33.20     31.76       32.52     42392222
# 2020-07-02      31.02      31.57     30.51       30.68     14981137
# 2020-07-01      30.96      31.27     30.16       30.43     13611544
#
# [105 rows x 5 columns]

# %%
uber_6_7 = pd.concat([uber_6, uber_7])
uber_6_7
# Out:
#             uber_open  uber_high  uber_low  uber_close  uber_volume
# Date
# 2024-06-28      70.81      73.26     70.77       72.68     21375880
# 2024-06-27      70.98      71.32     70.07       70.34      9650481
# 2024-06-26      70.94      71.60     70.55       70.85     10232568
# 2024-06-25      71.86      72.94     70.22       71.38     18911562
# 2024-06-24      69.83      71.23     69.75       70.54     12479277
# ...               ...        ...       ...         ...          ...
# 2020-07-08      33.21      33.97     32.68       33.93     24602369
# 2020-07-07      32.46      33.56     32.39       32.82     34874658
# 2020-07-06      33.10      33.20     31.76       32.52     42392222
# 2020-07-02      31.02      31.57     30.51       30.68     14981137
# 2020-07-01      30.96      31.27     30.16       30.43     13611544
#
# [210 rows x 5 columns]
