# %% [markdown]
# <a href="https://colab.research.google.com/github/sebakrys/data-science-bootcamp-A-Z/blob/main/06_Dane_gieldowe_pt2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

print('Numpy:', np.__version__)
print('Pandas:', pd.__version__)
# Out:
# Numpy: 1.26.4
# Pandas: 2.1.4

# %%
from os import name
def fetch_financial_data(company="AMZN"):
  """Fetch stock data from stooq.pl service"""
  import pandas_datareader.data as web
  return web.DataReader(name=company, data_source='stooq')

# %%
df =fetch_financial_data("META")
df.head()
# Out:
#               Open      High       Low   Close    Volume
# Date
# 2024-09-27  570.10  570.8399  564.5100  567.36   9398367
# 2024-09-26  575.73  577.4000  562.3501  567.84  14400787
# 2024-09-25  564.05  576.8800  563.7200  568.31  16543350
# 2024-09-24  566.68  567.7450  554.1900  563.33  12992956
# 2024-09-23  569.50  573.9799  562.4100  564.41  12830669

# %% [markdown]
# ## Save to file

# %%
df.to_csv('meta.csv')

# %%
df_nov = df[(df.index.month==11) & (df.index.year==2023)]
df_nov
# Out:
#                Open      High       Low   Close    Volume
# Date
# 2023-11-30  331.890  333.5000  322.4037  327.15  23146387
# 2023-11-29  339.690  339.9000  330.7800  332.20  16024497
# 2023-11-28  333.400  339.3750  333.4000  338.99  12637245
# 2023-11-27  336.180  339.9000  334.2000  334.70  15684454
# 2023-11-24  340.130  341.8556  336.7700  338.23   5467488
# 2023-11-22  339.210  342.9200  338.5800  341.49  10715177
# 2023-11-21  338.330  339.9015  335.9000  336.98  12027863
# 2023-11-20  334.890  341.8700  334.1900  339.97  16976129
# 2023-11-17  330.260  335.5000  329.3500  335.04  14519213
# 2023-11-16  329.370  334.5800  326.3800  334.19  18932572
# 2023-11-15  337.930  338.4000  330.0200  332.71  14531180
# 2023-11-14  334.540  338.1000  333.3300  336.31  17179403
# 2023-11-13  326.200  332.3300  325.7000  329.19  16908948
# 2023-11-10  319.940  329.1000  319.4600  328.77  19116921
# 2023-11-09  319.418  324.1799  318.8000  320.55  16103071
# ...

# %%
df_nov.to_csv('meta_nov.csv')

# %%
new_df = pd.read_csv('meta_nov.csv', index_col=0)
new_df
# Out:
#                Open      High       Low   Close    Volume
# Date
# 2023-11-30  331.890  333.5000  322.4037  327.15  23146387
# 2023-11-29  339.690  339.9000  330.7800  332.20  16024497
# 2023-11-28  333.400  339.3750  333.4000  338.99  12637245
# 2023-11-27  336.180  339.9000  334.2000  334.70  15684454
# 2023-11-24  340.130  341.8556  336.7700  338.23   5467488
# 2023-11-22  339.210  342.9200  338.5800  341.49  10715177
# 2023-11-21  338.330  339.9015  335.9000  336.98  12027863
# 2023-11-20  334.890  341.8700  334.1900  339.97  16976129
# 2023-11-17  330.260  335.5000  329.3500  335.04  14519213
# 2023-11-16  329.370  334.5800  326.3800  334.19  18932572
# 2023-11-15  337.930  338.4000  330.0200  332.71  14531180
# 2023-11-14  334.540  338.1000  333.3300  336.31  17179403
# 2023-11-13  326.200  332.3300  325.7000  329.19  16908948
# 2023-11-10  319.940  329.1000  319.4600  328.77  19116921
# 2023-11-09  319.418  324.1799  318.8000  320.55  16103071
# ...

# %%
df_nov.to_excel('meta_nov.xlsx')

# %%
new_df = pd.read_excel('meta_nov.xlsx', index_col=0)
new_df
# Out:
#                Open      High       Low   Close    Volume
# Date
# 2023-11-30  331.890  333.5000  322.4037  327.15  23146387
# 2023-11-29  339.690  339.9000  330.7800  332.20  16024497
# 2023-11-28  333.400  339.3750  333.4000  338.99  12637245
# 2023-11-27  336.180  339.9000  334.2000  334.70  15684454
# 2023-11-24  340.130  341.8556  336.7700  338.23   5467488
# 2023-11-22  339.210  342.9200  338.5800  341.49  10715177
# 2023-11-21  338.330  339.9015  335.9000  336.98  12027863
# 2023-11-20  334.890  341.8700  334.1900  339.97  16976129
# 2023-11-17  330.260  335.5000  329.3500  335.04  14519213
# 2023-11-16  329.370  334.5800  326.3800  334.19  18932572
# 2023-11-15  337.930  338.4000  330.0200  332.71  14531180
# 2023-11-14  334.540  338.1000  333.3300  336.31  17179403
# 2023-11-13  326.200  332.3300  325.7000  329.19  16908948
# 2023-11-10  319.940  329.1000  319.4600  328.77  19116921
# 2023-11-09  319.418  324.1799  318.8000  320.55  16103071
# ...
