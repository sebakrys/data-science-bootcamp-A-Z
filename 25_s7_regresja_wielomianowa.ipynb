# %% [markdown]
# <a href="https://colab.research.google.com/github/sebakrys/data-science-bootcamp-A-Z/blob/main/25_s7_regresja_wielomianowa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Dopsaownie modelu do danych o postaci wielomianowej, wykorzystując regresję liniową

# %%
import sklearn
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
np.random.seed(0)
X = np.arange(-10, 10, 0.5)
noise = 80 * np.random.randn(40)
y = -X**3 + 10*X**2 - 2*X + 3 + noise
X = X.reshape(40, 1)
_ = plt.scatter(X, y)

# %%
from sklearn.linear_model import LinearRegression

regresion = LinearRegression()
regresion.fit(X, y)
y_pred = regresion.predict(X)

plt.scatter(X, y)
plt.plot(X, y_pred, c='violet')

# %%
from sklearn.metrics import r2_score

r2_score(y, y_pred)
# Out:
# 0.5398062344255777

# %%
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)
X_poly
# Out:
# array([[  1.  , -10.  , 100.  ],
#        [  1.  ,  -9.5 ,  90.25],
#        [  1.  ,  -9.  ,  81.  ],
#        [  1.  ,  -8.5 ,  72.25],
#        [  1.  ,  -8.  ,  64.  ],
#        [  1.  ,  -7.5 ,  56.25],
#        [  1.  ,  -7.  ,  49.  ],
#        [  1.  ,  -6.5 ,  42.25],
#        [  1.  ,  -6.  ,  36.  ],
#        [  1.  ,  -5.5 ,  30.25],
#        [  1.  ,  -5.  ,  25.  ],
#        [  1.  ,  -4.5 ,  20.25],
#        [  1.  ,  -4.  ,  16.  ],
#        [  1.  ,  -3.5 ,  12.25],
#        [  1.  ,  -3.  ,   9.  ],
#        [  1.  ,  -2.5 ,   6.25],
#        [  1.  ,  -2.  ,   4.  ],
#        [  1.  ,  -1.5 ,   2.25],
#        [  1.  ,  -1.  ,   1.  ],
#        [  1.  ,  -0.5 ,   0.25],
#        [  1.  ,   0.  ,   0.  ],
#        [  1.  ,   0.5 ,   0.25],
#        [  1.  ,   1.  ,   1.  ],
#        [  1.  ,   1.5 ,   2.25],
#        [  1.  ,   2.  ,   4.  ],
#        [  1.  ,   2.5 ,   6.25],
#        [  1.  ,   3.  ,   9.  ],
#        [  1.  ,   3.5 ,  12.25],
# ...

# %%
regressor_poly = LinearRegression()
regressor_poly.fit(X_poly, y)

y_pred = regressor_poly.predict(X_poly)

plt.scatter(X, y)
plt.plot(X, y_pred, c='r')

# %%
r2_score(y, y_pred=y_pred)
# Out:
# 0.9000601519884677

# %% [markdown]
# ## Cechy wielomianowe - 3. stopien

# %%
np.set_printoptions(suppress=True)
poly = PolynomialFeatures(degree=3)
X_poly = poly.fit_transform(X)
X_poly
# Out:
# array([[    1.   ,   -10.   ,   100.   , -1000.   ],
#        [    1.   ,    -9.5  ,    90.25 ,  -857.375],
#        [    1.   ,    -9.   ,    81.   ,  -729.   ],
#        [    1.   ,    -8.5  ,    72.25 ,  -614.125],
#        [    1.   ,    -8.   ,    64.   ,  -512.   ],
#        [    1.   ,    -7.5  ,    56.25 ,  -421.875],
#        [    1.   ,    -7.   ,    49.   ,  -343.   ],
#        [    1.   ,    -6.5  ,    42.25 ,  -274.625],
#        [    1.   ,    -6.   ,    36.   ,  -216.   ],
#        [    1.   ,    -5.5  ,    30.25 ,  -166.375],
#        [    1.   ,    -5.   ,    25.   ,  -125.   ],
#        [    1.   ,    -4.5  ,    20.25 ,   -91.125],
#        [    1.   ,    -4.   ,    16.   ,   -64.   ],
#        [    1.   ,    -3.5  ,    12.25 ,   -42.875],
#        [    1.   ,    -3.   ,     9.   ,   -27.   ],
#        [    1.   ,    -2.5  ,     6.25 ,   -15.625],
#        [    1.   ,    -2.   ,     4.   ,    -8.   ],
#        [    1.   ,    -1.5  ,     2.25 ,    -3.375],
# ...

# %%
regressor_poly3 = LinearRegression()
regressor_poly3.fit(X_poly, y)

y_pred = regressor_poly3.predict(X_poly)

plt.scatter(X, y)
plt.plot(X, y_pred, c='r')

# %%
r2_score(y, y_pred)
# Out:
# 0.9793138557357745
